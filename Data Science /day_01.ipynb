# %%
print("Hello!")
# Out:
# Hello!

# %% [markdown]
# # Welcome to python noteboook.
# ### Day 1
#
# This is where I can write my notes. One # is big heading. ## is like h2 and so on.

# %%
for i in range(5):
    print(f"i is {i}")
# Out:
# i is 0
# i is 1
# i is 2
# i is 3
# i is 4
